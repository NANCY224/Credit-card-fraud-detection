# %%
from pycaret.utils import version
version()
# Out:
# 1.0.0

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\NANCY\Desktop\Dataset\creditcard.csv\creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
len(data[data['Class']== 0])
# Out:
# 284315

# %%
len(data[data['Class']== 1])
# Out:
# 492

# %%
from pycaret.classification import *
clf1 = setup(data = data, target = 'Class')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_e2ce5afa_9506_11ea_b215_c8d9d281897e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e2ce5afa_9506_11ea_b215_c8d9d281897elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e2ce5afa_9506_11ea_b215_c8d9d281897erow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e2ce5afa_9506_11ea_b215_c8d9d281897erow0_col1" class="data row0 col1" >8542</td>
#             </tr>
#             <tr>
#                         <th id="T_e2ce5afa_9506_11ea_b215_c8d9d281897elevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e2ce5afa_9506_11ea_b215_c8d9d281897erow1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_d25b549c_950c_11ea_9fcb_c8d9d281897e th {
#           text-align: left;
#     }    #T_d25b549c_950c_11ea_9fcb_c8d9d281897erow0_col0 {
#             text-align:  left;
#         }    #T_d25b549c_950c_11ea_9fcb_c8d9d281897erow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d25b549c_950c_11ea_9fcb_c8d9d281897erow0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_d25b549c_950c_11ea_9fcb_c8d9d281897erow0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_d25b549c_950c_11ea_9fcb_c8d9d281897erow0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_d25b549c_950c_11ea_9fcb_c8d9d281897erow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_d25b549c_950c_11ea_9fcb_c8d9d281897erow0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_d25b549c_950c_11ea_9fcb_c8d9d281897erow1_col0 {
# ...

# %%
random_forest = create_model('rf')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9997  0.9373  0.8333  1.0000  0.9091  0.9089
# 1       0.9996  0.9582  0.7917  1.0000  0.8837  0.8835
# 2       0.9996  0.9372  0.8333  0.9524  0.8889  0.8887
# 3       0.9994  0.9598  0.6800  1.0000  0.8095  0.8092
# 4       0.9996  0.9163  0.7500  1.0000  0.8571  0.8569
# 5       0.9993  0.9371  0.7083  0.8500  0.7727  0.7724
# 6       0.9992  0.8329  0.5417  1.0000  0.7027  0.7023
# 7       0.9995  0.9577  0.7500  0.9474  0.8372  0.8370
# 8       0.9994  0.8954  0.7500  0.9000  0.8182  0.8179
# 9       0.9994  0.9163  0.7500  0.8571  0.8000  0.7997
# Mean    0.9995  0.9248  0.7388  0.9507  0.8279  0.8277
# SD      0.0002  0.0365  0.0803  0.0580  0.0586  0.0586

# %%
tuned_random_forest = tune_model('rf')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9997  0.9370  0.8333  1.0000  0.9091  0.9089
# 1       0.9998  0.9580  0.8750  1.0000  0.9333  0.9332
# 2       0.9996  0.9577  0.7917  0.9500  0.8636  0.8634
# 3       0.9997  0.9597  0.8400  1.0000  0.9130  0.9129
# 4       0.9996  0.9159  0.7917  1.0000  0.8837  0.8835
# 5       0.9995  0.9369  0.8333  0.8696  0.8511  0.8508
# 6       0.9993  0.8532  0.5833  1.0000  0.7368  0.7365
# 7       0.9995  0.9368  0.7500  0.9474  0.8372  0.8370
# 8       0.9994  0.9158  0.7500  0.9000  0.8182  0.8179
# 9       0.9995  0.9367  0.7500  0.9474  0.8372  0.8370
# Mean    0.9996  0.9307  0.7798  0.9614  0.8583  0.8581
# SD      0.0001  0.0299  0.0774  0.0449  0.0540  0.0541

# %%
plot_model(estimator = tuned_random_forest , plot = 'learning')

# %%
plot_model(estimator = tuned_random_forest , plot = 'auc')

# %%
plot_model(estimator = tuned_random_forest , plot = 'pr')

# %%
plot_model(estimator = tuned_random_forest , plot = 'confusion_matrix')

# %%
plot_model(estimator = tuned_random_forest, plot = 'feature')

# %%
plot_model(estimator = tuned_random_forest, plot = 'error')

# %%
plot_model(estimator = tuned_random_forest, plot = 'class_report')

# %%
interpret_model(tuned_random_forest)

# %%
interpret_model(tuned_random_forest, plot = 'correlation')

# %%
Extra_tree_classifier = create_model('et')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9997  0.9358  0.8333  1.0000  0.9091  0.9089
# 1       0.9997  0.9992  0.8333  1.0000  0.9091  0.9089
# 2       0.9996  0.9566  0.7917  0.9500  0.8636  0.8634
# 3       0.9998  0.9588  0.8800  1.0000  0.9362  0.9361
# 4       0.9996  0.9354  0.7500  1.0000  0.8571  0.8569
# 5       0.9994  0.9776  0.7500  0.8571  0.8000  0.7997
# 6       0.9992  0.8716  0.5417  1.0000  0.7027  0.7023
# 7       0.9995  0.9357  0.7917  0.9048  0.8444  0.8442
# 8       0.9994  0.8929  0.7500  0.9000  0.8182  0.8179
# 9       0.9994  0.9563  0.7500  0.9000  0.8182  0.8179
# Mean    0.9995  0.9420  0.7672  0.9512  0.8459  0.8456
# SD      0.0002  0.0357  0.0864  0.0531  0.0638  0.0639

# %%
tuned_extra_tree_classifier = tune_model('et')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9997  0.9368  0.8333  1.0000  0.9091  0.9089
# 1       0.9997  0.9998  0.8333  1.0000  0.9091  0.9089
# 2       0.9996  0.9579  0.7500  1.0000  0.8571  0.8569
# 3       0.9996  0.9594  0.8000  1.0000  0.8889  0.8887
# 4       0.9995  0.9367  0.7083  1.0000  0.8293  0.8290
# 5       0.9993  0.9366  0.7500  0.8182  0.7826  0.7823
# 6       0.9993  0.8526  0.5833  1.0000  0.7368  0.7365
# 7       0.9994  0.9368  0.7917  0.8636  0.8261  0.8258
# 8       0.9994  0.9355  0.7083  0.8947  0.7907  0.7904
# 9       0.9994  0.9366  0.7500  0.9000  0.8182  0.8179
# Mean    0.9995  0.9389  0.7508  0.9477  0.8348  0.8345
# SD      0.0002  0.0346  0.0703  0.0673  0.0540  0.0540

# %%
plot_model(estimator = tuned_extra_tree_classifier , plot = 'learning')

# %%
plot_model(estimator = tuned_extra_tree_classifier, plot = 'auc')

# %%
plot_model(estimator = tuned_extra_tree_classifier, plot = 'pr')

# %%
plot_model(estimator = tuned_extra_tree_classifier, plot = 'confusion_matrix')

# %%
plot_model(estimator = tuned_extra_tree_classifier, plot = 'feature')

# %%
plot_model(estimator = tuned_extra_tree_classifier, plot = 'error')

# %%
plot_model(estimator = tuned_extra_tree_classifier, plot = 'class_report')

# %%
interpret_model(tuned_extra_tree_classifier)

# %%
interpret_model(tuned_extra_tree_classifier, plot = 'correlation')

# %%
xgboost_model = create_model('xgboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9997  0.9838  0.8333  1.0000  0.9091  0.9089
# 1       0.9996  0.9996  0.7917  1.0000  0.8837  0.8835
# 2       0.9995  0.9917  0.7917  0.9048  0.8444  0.8442
# 3       0.9996  0.9913  0.8000  0.9524  0.8696  0.8694
# 4       0.9996  0.9542  0.7917  0.9500  0.8636  0.8634
# 5       0.9995  0.9658  0.8333  0.8696  0.8511  0.8508
# 6       0.9992  0.9169  0.5417  1.0000  0.7027  0.7023
# 7       0.9994  0.9656  0.7500  0.8571  0.8000  0.7997
# 8       0.9991  0.9284  0.7500  0.7200  0.7347  0.7342
# 9       0.9994  0.9875  0.7083  0.9444  0.8095  0.8092
# Mean    0.9995  0.9685  0.7592  0.9198  0.8268  0.8266
# SD      0.0002  0.0267  0.0812  0.0827  0.0624  0.0625

# %%
tuned_xgboost = tune_model('xgboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9997  0.9678  0.8333  1.0000  0.9091  0.9089
# 1       0.9996  0.9975  0.8333  0.9524  0.8889  0.8887
# 2       0.9995  0.9923  0.7500  0.9474  0.8372  0.8370
# 3       0.9996  0.9792  0.8400  0.9545  0.8936  0.8934
# 4       0.9995  0.9500  0.7500  0.9474  0.8372  0.8370
# 5       0.9994  0.9781  0.7917  0.8261  0.8085  0.8082
# 6       0.9992  0.9377  0.5417  1.0000  0.7027  0.7023
# 7       0.9996  0.9200  0.8333  0.9091  0.8696  0.8694
# 8       0.9994  0.9552  0.7500  0.8571  0.8000  0.7997
# 9       0.9994  0.9814  0.7083  0.9444  0.8095  0.8092
# Mean    0.9995  0.9659  0.7632  0.9338  0.8356  0.8354
# SD      0.0001  0.0235  0.0861  0.0530  0.0575  0.0576

# %%
plot_model(estimator = tuned_xgboost, plot = 'learning')

# %%
plot_model(estimator = tuned_xgboost, plot = 'auc')

# %%
plot_model(estimator = tuned_xgboost, plot = 'pr')

# %%
plot_model(estimator = tuned_xgboost, plot = 'confusion_matrix')

# %%
plot_model(estimator = tuned_xgboost, plot = 'feature')

# %%
plot_model(estimator = tuned_xgboost, plot = 'error')

# %%
plot_model(estimator = tuned_xgboost, plot = 'class_report')

# %%
interpret_model(tuned_xgboost)

# %%
interpret_model(tuned_xgboost, plot = 'correlation')
